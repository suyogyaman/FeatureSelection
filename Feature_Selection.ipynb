# %% [markdown]
# # Feature Selection via 3 different techniques

# %% [markdown]
# We used three different techniques :
# 1. Univariate Selection
# 2. Feature Importance
# 3. Correlation Matrix with Heatmap
#
# Dataset is classification of mobile price range according to different features. We will analyze which one has the most effect.

# %%
#Importing Libraries
import pandas as pd
import numpy as np

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
#Importing dataset 
dataset = pd.read_csv('train.csv')
dataset.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
#Splitting the dataset to train and test set 
X = dataset.iloc[:,0:20] #independent feature
y = dataset.iloc[:,-1] #output , i.e. price range

# %% [markdown]
# ## Univariate Selection

# %%
#Apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2,k=10)
fit = bestfeatures.fit(X,y)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfscores
# Out:
#                 0
# 0    14129.866576
# 1        0.723232
# 2        0.648366
# 3        0.631011
# 4       10.135166
# 5        1.521572
# 6       89.839124
# 7        0.745820
# 8       95.972863
# 9        9.097556
# 10       9.186054
# 11   17363.569536
# 12    9810.586750
# 13  931267.519053
# 14       9.614878
# 15      16.480319
# 16      13.236400
# 17       0.327643
# 18       1.928429
# 19       0.422091

# %%
dfcolumns = pd.DataFrame(X.columns)

# %%
dfcolumns
# Out:
#                 0
# 0   battery_power
# 1            blue
# 2     clock_speed
# 3        dual_sim
# 4              fc
# 5          four_g
# 6      int_memory
# 7           m_dep
# 8       mobile_wt
# 9         n_cores
# 10             pc
# 11      px_height
# 12       px_width
# 13            ram
# 14           sc_h
# 15           sc_w
# 16      talk_time
# 17        three_g
# 18   touch_screen
# 19           wifi

# %%
#concat these two columns
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']
featureScores
# Out:
#             Specs          Score
# 0   battery_power   14129.866576
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 4              fc      10.135166
# 5          four_g       1.521572
# 6      int_memory      89.839124
# 7           m_dep       0.745820
# 8       mobile_wt      95.972863
# 9         n_cores       9.097556
# 10             pc       9.186054
# 11      px_height   17363.569536
# 12       px_width    9810.586750
# 13            ram  931267.519053
# 14           sc_h       9.614878
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 17        three_g       0.327643
# 18   touch_screen       1.928429
# 19           wifi       0.422091

# %%
print(featureScores.nlargest(10,'Score'))  #Top 10 features that effect price range of mobile
# Out:
#             Specs          Score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878

# %% [markdown]
# ## Feature Importance

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt

# %%
model = ExtraTreesClassifier()
model.fit(X,y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#                      max_depth=None, max_features='auto', max_leaf_nodes=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#                      oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
print(model.feature_importances_) # inbuilt class feature_importance of tree based classifiers
# Out:
# [0.0550885  0.02102304 0.03956117 0.02236334 0.03575129 0.02109317
#  0.03817078 0.03553658 0.03619674 0.03544123 0.03804688 0.04800428
#  0.04878023 0.3508236  0.03875523 0.03779235 0.03839284 0.01634275
#  0.02052553 0.02231047]

# %%
#plot graph 
feat_importances = pd.Series(model.feature_importances_,index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# ## Correlation Matrix with Heatmap

# %%
import seaborn as sns
corrmat = dataset.corr() # get correlations of each features in dataset
corrmat
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
top_corr_features = corrmat.index
top_corr_features
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
plt.figure(figsize=(20,20))
g = sns.heatmap(dataset[top_corr_features].corr(),annot=True)
